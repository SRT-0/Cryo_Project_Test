# %%
# %pip install mrcfile
# Out:
# Collecting mrcfile
#   Downloading mrcfile-1.5.4-py2.py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from mrcfile) (2.0.2)
# Downloading mrcfile-1.5.4-py2.py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: mrcfile
# Successfully installed mrcfile-1.5.4

# %%
import os
import sys
import numpy as np
import mrcfile
from PIL import Image
from sklearn.model_selection import train_test_split

# %%
# @title mount colab
from google.colab import drive
drive.mount('/content/drive')
print("mounted")
# Out:
# Mounted at /content/drive
# mounted

# %%
# @title  { display-mode: "form" }
# @markdown Directory parameters

DATA_DIR = "/content/drive/MyDrive/cryo_project/Test_on_10017/Test_0_9-8_9-30_EM_10017/data" # @param {type:"string"}
RESULT_DIR = "/content/drive/MyDrive/cryo_project/Test_on_10017/Test_0_9-8_9-30_EM_10017/C-CSN-D_float-u_output" # @param {type:"string"}
TMP_DIR = "/content/tmp" # @param {type:"string"}
SOFTWARE_DIR = "/content/software" # @param {type:"string"}
WORK_DIR = os.getcwd()

# !mkdir {RESULT_DIR}
# !mkdir {TMP_DIR}
# !mkdir {SOFTWARE_DIR}
# Out:
# mkdir: cannot create directory ‘/content/tmp’: File exists
# mkdir: cannot create directory ‘/content/software’: File exists

# %%
EMPIAR_ID = "10017" # @param{type: "string"}

# %%
# @title  { display-mode: "form" }
denoised = "Conv CryoSegNet Denoise Process" # @param ["other", "Topaz Denoise", "Conv CryoSegNet Denoise Process"]

denoise_prefix = ""
if denoised == "Topaz Denoise":
    denoise_prefix = "TpzD_"
if denoised == "Conv CryoSegNet Denoise Process":
    denoise_prefix = "C-CSN-D_"

# @markdown ---
extra = True # @param{type: "boolean"}
if extra == True:
    extra_prefix = "float-u" # @param{type: "string"}
    denoise_prefix = denoise_prefix + extra_prefix + "_"

# %%
# @title  { display-mode: "form" }

TOPAZ_INSTALL = True # @param {type:"boolean"}

if TOPAZ_INSTALL:
  # %cd {SOFTWARE_DIR_PATH}
  # !git clone https://github.com/tbepler/topaz.git
  # %cd topaz
  # !pip install -e .
  # %cd ..

topaz_path = os.path.join(os.getcwd(), 'topaz')
if topaz_path not in sys.path:
    sys.path.insert(0, topaz_path)

print(f"Added {topaz_path} to the Python path.")
# Out:
# [Errno 2] No such file or directory: '{SOFTWARE_DIR_PATH}'
# /content
# Cloning into 'topaz'...
# remote: Enumerating objects: 3509, done.
# remote: Counting objects: 100% (573/573), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 3509 (delta 540), reused 490 (delta 490), pack-reused 2936 (from 2)
# Receiving objects: 100% (3509/3509), 253.10 MiB | 25.86 MiB/s, done.
# Resolving deltas: 100% (2292/2292), done.
# /content/topaz
# Obtaining file:///content/topaz
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from topaz-em==0.3.16) (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from topaz-em==0.3.16) (0.23.0+cu126)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from topaz-em==0.3.16) (4.67.1)
# Requirement already satisfied: h5py>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from topaz-em==0.3.16) (3.14.0)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.12/dist-packages (from topaz-em==0.3.16) (2.0.2)
# Requirement already satisfied: pandas>=0.20.3 in /usr/local/lib/python3.12/dist-packages (from topaz-em==0.3.16) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from topaz-em==0.3.16) (1.6.1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.12/dist-packages (from topaz-em==0.3.16) (1.16.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from topaz-em==0.3.16) (11.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from topaz-em==0.3.16) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.20.3->topaz-em==0.3.16) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.20.3->topaz-em==0.3.16) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.20.3->topaz-em==0.3.16) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.19.0->topaz-em==0.3.16) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.19.0->topaz-em==0.3.16) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->topaz-em==0.3.16) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->topaz-em==0.3.16) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->topaz-em==0.3.16) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->topaz-em==0.3.16) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->topaz-em==0.3.16) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->topaz-em==0.3.16) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->topaz-em==0.3.16) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->topaz-em==0.3.16) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->topaz-em==0.3.16) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->topaz-em==0.3.16) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->topaz-em==0.3.16) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->topaz-em==0.3.16) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->topaz-em==0.3.16) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->topaz-em==0.3.16) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->topaz-em==0.3.16) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->topaz-em==0.3.16) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->topaz-em==0.3.16) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->topaz-em==0.3.16) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->topaz-em==0.3.16) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->topaz-em==0.3.16) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->topaz-em==0.3.16) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.0.0->topaz-em==0.3.16) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=0.20.3->topaz-em==0.3.16) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.0.0->topaz-em==0.3.16) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.0.0->topaz-em==0.3.16) (3.0.3)
# Building wheels for collected packages: topaz-em
#   Building editable for topaz-em (pyproject.toml) ... done
#   Created wheel for topaz-em: filename=topaz_em-0.3.16-0.editable-py3-none-any.whl size=23634 sha256=0f7a963fcee39cf401cca644e11fde6d7adf032e02d651a590e59946247fd7fb
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_b4lz7y0/wheels/34/0d/e5/4087eebff1752f9d02379efa7899df182aacbd78548ff622ce
# Successfully built topaz-em
# Installing collected packages: topaz-em
# Successfully installed topaz-em-0.3.16
# /content
# Added /content/topaz to the Python path.

# %%
# @title  { vertical-output: true, display-mode: "form" }
# @markdown Preprocess the micrograph using topaz.
# !mkdir {RESULT_DIR}/dataset/{EMPIAR_ID}/processed_micrographs
# !topaz preprocess -v -o {TMP_DIR}/micrographs/ {DATA_DIR}/EMPIAR-{EMPIAR_ID}/{denoise_prefix}micrographs/*.mrc --device 0
# !rsync -av {TMP_DIR}/micrographs/* {RESULT_DIR}/dataset/{EMPIAR_ID}/processed_micrographs/
# Out:
# SyntaxWarning: invalid escape sequence '\s'
# SyntaxWarning: invalid escape sequence '\s'
# CudaWarning: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx
# Falling back to CPU.
# # processed: Falcon_2012_06_12-14_33_35_0
# # processed: Falcon_2012_06_12-14_57_34_0
# # processed: Falcon_2012_06_12-15_07_41_0
# # processed: Falcon_2012_06_12-15_14_01_0
# # processed: Falcon_2012_06_12-15_17_31_0
# # processed: Falcon_2012_06_12-15_27_22_0
# # processed: Falcon_2012_06_12-15_30_21_0
# # processed: Falcon_2012_06_12-15_33_42_0
# # processed: Falcon_2012_06_12-15_36_26_0
# # processed: Falcon_2012_06_12-15_41_22_0
# # processed: Falcon_2012_06_12-15_43_48_0
# # processed: Falcon_2012_06_12-15_46_37_0
# # processed: Falcon_2012_06_12-15_53_09_0
# # processed: Falcon_2012_06_12-16_26_22_0
# # processed: Falcon_2012_06_12-16_44_07_0
# # processed: Falcon_2012_06_12-16_48_06_0
# # processed: Falcon_2012_06_12-16_51_03_0
# # processed: Falcon_2012_06_12-16_55_40_0
# # processed: Falcon_2012_06_12-16_59_12_0
# # processed: Falcon_2012_06_12-17_02_43_0
# # processed: Falcon_2012_06_12-17_14_17_0
# # processed: Falcon_2012_06_12-17_17_05_0
# # processed: Falcon_2012_06_12-17_23_32_0
# # processed: Falcon_2012_06_12-17_26_54_0
# # processed: Falcon_2012_06_12-17_34_38_0
# # processed: Falcon_2012_06_12-17_37_29_0
# # processed: Falcon_2012_06_12-17_40_47_0
# # processed: Falcon_2012_06_12-17_46_08_0
# # processed: Falcon_2012_06_12-17_49_17_0
# # processed: Falcon_2012_06_12-18_07_45_0
# # processed: Falcon_2012_06_12-18_10_19_0
# # processed: Falcon_2012_06_12-18_13_12_0
# # processed: Falcon_2012_06_12-18_21_21_0
# # processed: Falcon_2012_06_12-19_07_37_0
# # processed: Falcon_2012_06_12-19_16_58_0
# # processed: Falcon_2012_06_12-19_21_25_0
# # processed: Falcon_2012_06_12-23_58_14_0
# # processed: Falcon_2012_06_13-00_13_13_0
# # processed: Falcon_2012_06_13-00_19_28_0
# # processed: Falcon_2012_06_13-00_24_19_0
# # processed: Falcon_2012_06_13-00_32_38_0
# # processed: Falcon_2012_06_13-00_45_25_0
# # processed: Falcon_2012_06_13-00_54_11_0
# # processed: Falcon_2012_06_13-00_59_38_0
# # processed: Falcon_2012_06_13-01_05_13_0
# Falcon_2012_06_13-10_20_02_0.mrc
# Falcon_2012_06_13-10_27_05_0.mrc
#
# sent 5,638,612,838 bytes  received 1,612 bytes  21,728,764.74 bytes/sec
# total size is 5,637,230,592  speedup is 1.00

# %%
"""
# @title  { vertical-output: true, display-mode: "form" }
# @markdown Rescalar and Store

input_dir = f'{TMP_DIR}/micrographs/'
output_dir = f'{RESULT_DIR}/dataset/{EMPIAR_ID}/{denoise_prefix}processed_micrographs_np/'

# Create the output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Loop through all files in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith('.mrc'):
        mrc_path = os.path.join(input_dir, filename)

        # Open the .mrc file
        with mrcfile.open(mrc_path) as mrcs:
            micrograph = mrcs.data

            normalized_micrograph = (micrograph - micrograph.min()) / (micrograph.max() - micrograph.min())

            # Scale to 0-255 and convert to uint8
            processed_micrograph = np.uint8(255 * normalized_micrograph)

            # Convert the NumPy array to a Pillow Image object
            img = Image.fromarray(processed_micrograph)

            # Save the image with a different extension (e.g., .png)
            output_filename = os.path.splitext(filename)[0] + '.png'
            output_path = os.path.join(output_dir, output_filename)
            img.save(output_path)

        print(f"Processed and saved {filename} to {output_filename}")
"""
# Out:
# '\n# @title  { vertical-output: true, display-mode: "form" }\n# @markdown Rescalar and Store\n\ninput_dir = f\'{TMP_DIR}/micrographs/\'\noutput_dir = f\'{RESULT_DIR}/dataset/{EMPIAR_ID}/{denoise_prefix}processed_micrographs_np/\'\n\n# Create the output directory if it doesn\'t exist\nos.makedirs(output_dir, exist_ok=True)\n\n# Loop through all files in the input directory\nfor filename in os.listdir(input_dir):\n    if filename.endswith(\'.mrc\'):\n        mrc_path = os.path.join(input_dir, filename)\n\n        # Open the .mrc file\n        with mrcfile.open(mrc_path) as mrcs:\n            micrograph = mrcs.data\n\n            normalized_micrograph = (micrograph - micrograph.min()) / (micrograph.max() - micrograph.min())\n\n            # Scale to 0-255 and convert to uint8\n            processed_micrograph = np.uint8(255 * normalized_micrograph)\n\n            # Convert the NumPy array to a Pillow Image object\n            img = Image.fromarray(processed_micrograph)\n\n            # Save the image with a different extension (e.g., .png)\n            output_filename = os.path.splitext(filename)[0] + \'.png\'\n            output_path = os.path.join(output_dir, output_filename)\n            img.save(output_path)\n\n        print(f"Processed and saved {filename} to {output_filename}")\n'

# %% [markdown]
# ---
# split

# %%
MRC_DIR = f'{RESULT_DIR}/dataset/{EMPIAR_ID}/processed_micrographs/'
SAVE_DIR = f"{RESULT_DIR}/dataset/{EMPIAR_ID}/processed_micrographs_np_split"

# %%
def save_mrc_to_npy(filenames, mrc_dir, save_dir, permissive=False):
  for filename in filenames:
    filepath = os.path.join(mrc_dir, filename)
    print("\rReading mrc:", filepath, end="", flush=True)
    with mrcfile.open(filepath, permissive=permissive) as mrc:
      basename, ext = os.path.splitext(filename)
      assert ext == ".mrc"
      print("\rConverting mrc to npy.", end="", flush=True)
      np.save(os.path.join(save_dir, basename), mrc.data)

# %%
# title Train test split

test_size = "0.83" # @param {type:"string"}
val_size = "0.071" # @param {type:"string"}
filenames = sorted(os.listdir(MRC_DIR))

test_size = float(test_size)
if test_size and not 0<=test_size<1:
  raise ValueError(f"`test_size` should be between 0.0 and 1.0, got: {test_size}")
val_size = float(val_size)
if val_size and not 0<=val_size<1:
  raise ValueError(f"`val_size` should be between 0.0 and 1.0, got: {val_size}")
train_size = 1 - test_size - val_size
if not 0<train_size<=1:
  raise ValueError(f"`val_size` + `test_size` should be between 0.0 and 1.0, got: {test_size + val_size}")
train_filenames, test_filenames = train_test_split(filenames, test_size=test_size, train_size=train_size, random_state=3)
train_filenames = sorted(train_filenames)
test_filenames = sorted(test_filenames)
val_filenames = []
for filename in filenames:
  if filename not in train_filenames and filename not in test_filenames:
    val_filenames.append(filename)
print("number of files:",
  f" train:\t{len(train_filenames)}",
  f" test:\t{len(test_filenames)}",
  f" val:\t{len(val_filenames)}", sep='\n')
# Out:
# number of files:
#  train:	8
#  test:	70
#  val:	6

# %%
# %%capture --no-display
# @title Generate np file from mrc files.
# @markdown note that directory for np files should not exist


PERMISSIVE = True # @param {type:"boolean"}

try:
    os.mkdir(SAVE_DIR)
except FileExistsError:
    pass

os.mkdir(os.path.join(SAVE_DIR, "train"))
save_mrc_to_npy(train_filenames,
                mrc_dir=MRC_DIR,
                save_dir=os.path.join(SAVE_DIR, "train"),
                permissive=PERMISSIVE)
np.savetxt(os.path.join(SAVE_DIR, "train_filenames.txt"), train_filenames, fmt="%s")

os.mkdir(os.path.join(SAVE_DIR, "test"))
save_mrc_to_npy(test_filenames, mrc_dir=MRC_DIR,
                save_dir=os.path.join(SAVE_DIR, "test"),
                permissive=PERMISSIVE)
np.savetxt(os.path.join(SAVE_DIR, "test_filenames.txt"), test_filenames, fmt="%s")

os.mkdir(os.path.join(SAVE_DIR, "val"))
save_mrc_to_npy(val_filenames, mrc_dir=MRC_DIR,
                save_dir=os.path.join(SAVE_DIR, "val"),
                permissive=PERMISSIVE)
np.savetxt(os.path.join(SAVE_DIR, "val_filenames.txt"), val_filenames, fmt="%s")

# %%
file_path = os.path.join(SAVE_DIR, 'train_filenames.txt')
file_path2 = os.path.join(SAVE_DIR, 'val_filenames.txt')
file_path3 = os.path.join(SAVE_DIR, 'test_filenames.txt')

with open(file_path, 'r') as f:
    train_filenames = [line.strip() for line in f if line.strip()]

with open(file_path2, 'r') as f:
    val_filenames = [line.strip() for line in f if line.strip()]

with open(file_path3, 'r') as f:
    test_filenames = [line.strip() for line in f if line.strip()]

print("number of files:",
  f" train:\t{len(train_filenames)}",
  f" test:\t{len(test_filenames)}",
  f" val:\t{len(val_filenames)}", sep='\n')
# Out:
# number of files:
#  train:	8
#  test:	70
#  val:	6

# %%
import matplotlib.pyplot as plt
from topaz.utils.data.loader import load_image

name = 'Falcon_2012_06_12-14_33_35_0' # @param {type: "string"}

mic = np.array(load_image(TMP_DIR + "/micrographs/" + name + '.mrc')[0], copy=False)

# scale them for visualization
mu = mic.mean()
std = mic.std()

mic = (mic - mu)/std

_,ax = plt.subplots(1,1,figsize=(24,12))

ax.imshow(mic, vmin=-4, vmax=4, cmap='Greys_r')
